# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_excel('NIHMS1531727-supplement-2.xlsx', sheet_name = 'SuppTable3', skiprows = 3)
df1
# Out:
#            Sample Chromosome      Start       Stop Reference Variant  \
# 0      su001_post          7   48266871   48266872         A       G
# 1      su001_post          7   48266871   48266872         A       G
# 2      su001_post          7   48266871   48266872         A       G
# 3      su001_post         17   67024726   67024727         C       T
# 4      su001_post         17   67024726   67024727         C       T
# ...           ...        ...        ...        ...       ...     ...
# 26258  su008_post          1  241938478  241938479         T       G
# 26259  su008_post         19   12384170   12384171         T       G
# 26260  su008_post         19   20728624   20728625         T       A
# 26261  su008_post         19   12501643   12501644         T       G
# 26262  su008_post          7    6661840    6661841         G       A
#
#       Gene.Name   HLA.Allele MT.Epitope.Seq WT.Epitope.Seq  \
# 0        ABCA13  HLA-B*27:05     NRTEEVILKL     NKTEEVILKL
# ...
