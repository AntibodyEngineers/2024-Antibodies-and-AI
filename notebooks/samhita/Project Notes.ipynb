# %% [markdown]
# **Two Projects**
# * Python-based AI/ML antibody engineering
# * R-based TCR dataset

# %% [markdown]
# **Getting Access to /data Folder in Jupyter Hub**

# %% [raw]
# ln -s /media/volume/... data

# %% [markdown]
# Open the terminal on your home page and type the above in. Tab after /media twice to automatically have '/volume' and '/...' filled in.

# %% [markdown]
# **Test**

# %%
import pandas
import numpy

df = pandas.read_excel('NIHMS1531727-supplement-2.xlsx')

# %%
df
# Out:
#    Supplementary Table 1: Clinical Metadata for Patient Cohort  Unnamed: 1  \
# 0   Clinical metadata including tumor type (basal ...                  NaN
# 1                                                 NaN                  NaN
# 2                                             Patient           Tumor Type
# 3                                               su001                  BCC
# 4                                               su002                  BCC
# 5                                               su003                  BCC
# 6                                               su004                  BCC
# 7                                               su005                  BCC
# 8                                               su006                  BCC
# 9                                               su007                  BCC
# 10                                              su008                  BCC
# ...
